# %%
#Implement a CSS grid layout to display a gallery of images in a grid format for design refer the image shown below, 
replace the empty boxed with actual images

""" To create a CSS grid layout for a gallery of images, you can use the following HTML and CSS code. Replace the 
    placeholder image URLs with your own image URLs to display the actual images.
    
    HTML:
    
    <div class="gallery">
  <div class="item"><img src="image-url-1.jpg" alt="Image 1"></div>
  <div class="item"><img src="image-url-2.jpg" alt="Image 2"></div>
  <div class="item"><img src="image-url-3.jpg" alt="Image 3"></div>
  <div class="item"><img src="image-url-4.jpg" alt="Image 4"></div>
  <div class="item"><img src="image-url-5.jpg" alt="Image 5"></div>
  <div class="item"><img src="image-url-6.jpg" alt="Image 6"></div>
  <div class="item"><img src="image-url-7.jpg" alt="Image 7"></div>
  <div class="item"><img src="image-url-8.jpg" alt="Image 8"></div>
  <div class="item"><img src="image-url-9.jpg" alt="Image 9"></div>
</div>


  CSS:
  
  .gallery {
  display: grid;
  grid-template-columns: repeat(3, 1fr);
  grid-gap: 10px;
}

.item {
  position: relative;
  overflow: hidden;
}

.item img {
  width: 100%;
  height: auto;
  display: block;
}

.item::before {
  content: "";
  display: block;
  padding-top: 100%;
}


  In the CSS code, we define a grid container with the class "gallery". It uses the display: grid property to create
  a grid layout. The grid-template-columns property sets the number of columns in the grid, in this case, we have 
  three columns, and 1fr means each column will have an equal fraction of the available space.

  The grid-gap property adds some spacing between the grid items. You can adjust the value as needed.

  Each gallery item is wrapped in a <div> element with the class "item". We set the position of the items to "relative" 
  and apply overflow: hidden to ensure that the images do not overflow outside their containers.

  The actual images are represented by the <img> elements, and we set their width to 100% to make them fit within their 
  containers while maintaining the aspect ratio. The display: block property removes any vertical spacing below the images.

  Lastly, we use the ::before pseudo-element to create a responsive aspect ratio for each item. It sets the height of the 
  item's container relative to its width, ensuring that the images maintain their aspect ratio even when the browser window 
  is resized.

  Remember to replace the "image-url-X.jpg" with the actual URLs of your images. You can add more or fewer <div> elements
  with the class "item" as needed for your gallery."""
